# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_weather_description = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | san quintin
# Processing Record 4 of Set 1 | caxias
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | fengcheng
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | pinczow
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | anadyr
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | fare
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | hirado
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | megion
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | keuruu
# Processing Record 36 of Set 1 | hamilton
# Processing Record 37 of Set 1 | cape coast
# Processing Record 38 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | lunenburg
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | port macquarie
# Processing Record 44 of Set 1 | asau
# Processing Record 45 of Set 1 | kobryn
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | sorland
# Processing Record 48 of Set 1 | lasa
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | bonfim
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | iranshahr
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 2 | vardo
# Processing Record 8 of Set 2 | kieta
# Processing Record 9 of Set 2 | oranjemund
# Processing Record 10 of Set 2 | payakumbuh
# Processing Record 11 of Set 2 | newport
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | batemans bay
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | ous
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | skelleftea
# Processing Record 20 of Set 2 | marolambo
# Processing Record 21 of Set 2 | sembakung
# Processing Record 22 of Set 2 | alta floresta
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | mollendo
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | karratha
# Processing Record 27 of Set 2 | pasighat
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | chengkung
# City not found. Skipping...
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | severo-yeniseyskiy
# Processing Record 33 of Set 2 | znamenskoye
# Processing Record 34 of Set 2 | flinders
# Processing Record 35 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | oussouye
# Processing Record 39 of Set 2 | alofi
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | manakara
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | comodoro rivadavia
# Processing Record 46 of Set 2 | makakilo city
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | teknaf
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | kasongo-lunda
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | khvastovichi
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | kutum
# Processing Record 10 of Set 3 | maceio
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | tagusao
# Processing Record 13 of Set 3 | nikolayevka
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | morgan city
# Processing Record 17 of Set 3 | eureka
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | tupelo
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | te anau
# Processing Record 24 of Set 3 | zhicheng
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | paamiut
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | khor
# Processing Record 30 of Set 3 | yulara
# Processing Record 31 of Set 3 | chapais
# Processing Record 32 of Set 3 | kattivakkam
# Processing Record 33 of Set 3 | cabildo
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | lucapa
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | vestmanna
# Processing Record 38 of Set 3 | sao filipe
# Processing Record 39 of Set 3 | ouango
# Processing Record 40 of Set 3 | manokwari
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | krutinka
# Processing Record 43 of Set 3 | acapulco
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | cayenne
# Processing Record 46 of Set 3 | sonepur
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | troitsko-pechorsk
# Processing Record 50 of Set 3 | ambon
# Processing Record 1 of Set 4 | jaque
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | inhambane
# Processing Record 6 of Set 4 | pankrushikha
# Processing Record 7 of Set 4 | omsukchan
# Processing Record 8 of Set 4 | taga
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | mnogovershinnyy
# Processing Record 11 of Set 4 | boende
# Processing Record 12 of Set 4 | flin flon
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | tutin
# Processing Record 15 of Set 4 | port hedland
# Processing Record 16 of Set 4 | severnyy
# Processing Record 17 of Set 4 | straumen
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | lang son
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | gilgit
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | brownwood
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | tuktoyaktuk
# Processing Record 29 of Set 4 | tadine
# Processing Record 30 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | gonen
# Processing Record 33 of Set 4 | san lorenzo
# Processing Record 34 of Set 4 | kloulklubed
# Processing Record 35 of Set 4 | villazon
# Processing Record 36 of Set 4 | sento se
# City not found. Skipping...
# Processing Record 37 of Set 4 | puerto quijarro
# Processing Record 38 of Set 4 | zapolyarnyy
# Processing Record 39 of Set 4 | dauphin
# Processing Record 40 of Set 4 | puerto ayora
# Processing Record 41 of Set 4 | kulhudhuffushi
# Processing Record 42 of Set 4 | kapaa
# Processing Record 43 of Set 4 | uchaly
# Processing Record 44 of Set 4 | mandalgovi
# Processing Record 45 of Set 4 | tuchola
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | palmer
# Processing Record 48 of Set 4 | luoyang
# Processing Record 49 of Set 4 | pacific grove
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | poum
# Processing Record 2 of Set 5 | lhuntshi
# City not found. Skipping...
# Processing Record 3 of Set 5 | kodiak
# Processing Record 4 of Set 5 | ivybridge
# Processing Record 5 of Set 5 | lawrenceburg
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | kaoma
# Processing Record 8 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 5 | beausejour
# Processing Record 10 of Set 5 | singaraja
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | burica
# City not found. Skipping...
# Processing Record 13 of Set 5 | seminole
# Processing Record 14 of Set 5 | iesolo
# Processing Record 15 of Set 5 | jiangyou
# Processing Record 16 of Set 5 | conceicao do araguaia
# Processing Record 17 of Set 5 | razole
# Processing Record 18 of Set 5 | klaksvik
# Processing Record 19 of Set 5 | bredasdorp
# Processing Record 20 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 5 | baruun-urt
# Processing Record 22 of Set 5 | broken hill
# Processing Record 23 of Set 5 | kulim
# Processing Record 24 of Set 5 | pyaozerskiy
# Processing Record 25 of Set 5 | cap malheureux
# Processing Record 26 of Set 5 | merrill
# Processing Record 27 of Set 5 | najran
# Processing Record 28 of Set 5 | corrente
# Processing Record 29 of Set 5 | autopan
# City not found. Skipping...
# Processing Record 30 of Set 5 | yima
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | roebourne
# Processing Record 33 of Set 5 | minab
# Processing Record 34 of Set 5 | vila franca do campo
# Processing Record 35 of Set 5 | wanaka
# Processing Record 36 of Set 5 | barnsley
# Processing Record 37 of Set 5 | lakselv
# Processing Record 38 of Set 5 | jalu
# Processing Record 39 of Set 5 | jasper
# Processing Record 40 of Set 5 | junnar
# Processing Record 41 of Set 5 | karsun
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | cefalu
# Processing Record 44 of Set 5 | padang
# Processing Record 45 of Set 5 | yabelo
# Processing Record 46 of Set 5 | bongandanga
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | nemuro
# Processing Record 50 of Set 5 | bauru
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | douglas
# Processing Record 3 of Set 6 | malchin
# Processing Record 4 of Set 6 | brigantine
# Processing Record 5 of Set 6 | corn island
# Processing Record 6 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | emba
# Processing Record 9 of Set 6 | shuangcheng
# Processing Record 10 of Set 6 | conde
# Processing Record 11 of Set 6 | asahikawa
# Processing Record 12 of Set 6 | dikson
# Processing Record 13 of Set 6 | aden
# Processing Record 14 of Set 6 | tasiilaq
# Processing Record 15 of Set 6 | cherskiy
# Processing Record 16 of Set 6 | sovetskaya gavan
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | pandan
# Processing Record 19 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 6 | mzimba
# Processing Record 21 of Set 6 | harper
# Processing Record 22 of Set 6 | quattro castella
# Processing Record 23 of Set 6 | biloela
# Processing Record 24 of Set 6 | coahuayana
# Processing Record 25 of Set 6 | ribeira grande
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | yershov
# Processing Record 28 of Set 6 | maxixe
# Processing Record 29 of Set 6 | navolato
# Processing Record 30 of Set 6 | parabel
# Processing Record 31 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 6 | quelimane
# Processing Record 33 of Set 6 | champasak
# Processing Record 34 of Set 6 | camana
# Processing Record 35 of Set 6 | umm lajj
# Processing Record 36 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 37 of Set 6 | nyurba
# Processing Record 38 of Set 6 | hasaki
# Processing Record 39 of Set 6 | russell
# Processing Record 40 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 6 | palu
# Processing Record 42 of Set 6 | mehamn
# Processing Record 43 of Set 6 | todos santos
# Processing Record 44 of Set 6 | saint-paul
# Processing Record 45 of Set 6 | hurzuf
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | mount gambier
# Processing Record 49 of Set 6 | zhenjiang
# Processing Record 50 of Set 6 | udachnyy
# Processing Record 1 of Set 7 | semey
# Processing Record 2 of Set 7 | walvis bay
# Processing Record 3 of Set 7 | westerland
# Processing Record 4 of Set 7 | kaniama
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | thinadhoo
# Processing Record 7 of Set 7 | basoko
# Processing Record 8 of Set 7 | clovis
# Processing Record 9 of Set 7 | ginda
# Processing Record 10 of Set 7 | necochea
# Processing Record 11 of Set 7 | chengdu
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | luderitz
# Processing Record 14 of Set 7 | mission
# Processing Record 15 of Set 7 | dongsheng
# Processing Record 16 of Set 7 | roberto payan
# City not found. Skipping...
# Processing Record 17 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 7 | kahului
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | sabang
# Processing Record 21 of Set 7 | ikungi
# Processing Record 22 of Set 7 | ozernovskiy
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | kurilsk
# Processing Record 25 of Set 7 | narasannapeta
# Processing Record 26 of Set 7 | muros
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | korla
# Processing Record 29 of Set 7 | leisure city
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | kyabe
# Processing Record 32 of Set 7 | peniche
# Processing Record 33 of Set 7 | naze
# Processing Record 34 of Set 7 | tutoia
# Processing Record 35 of Set 7 | gurlan
# Processing Record 36 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 37 of Set 7 | namatanai
# Processing Record 38 of Set 7 | pangoa
# Processing Record 39 of Set 7 | tuatapere
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 42 of Set 7 | opuwo
# Processing Record 43 of Set 7 | yerbogachen
# Processing Record 44 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 7 | ugoofaaru
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | lebu
# Processing Record 49 of Set 7 | provideniya
# Processing Record 50 of Set 7 | boda
# Processing Record 1 of Set 8 | kununurra
# Processing Record 2 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 8 | jinchang
# Processing Record 4 of Set 8 | houlton
# Processing Record 5 of Set 8 | erzin
# Processing Record 6 of Set 8 | fort frances
# Processing Record 7 of Set 8 | anloga
# Processing Record 8 of Set 8 | qaqortoq
# Processing Record 9 of Set 8 | quesnel
# Processing Record 10 of Set 8 | kangaatsiaq
# Processing Record 11 of Set 8 | mogadishu
# Processing Record 12 of Set 8 | puerto carreno
# Processing Record 13 of Set 8 | penzance
# Processing Record 14 of Set 8 | bethel
# Processing Record 15 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 8 | yar-sale
# Processing Record 17 of Set 8 | mount isa
# Processing Record 18 of Set 8 | honiara
# Processing Record 19 of Set 8 | muli
# Processing Record 20 of Set 8 | freeport
# Processing Record 21 of Set 8 | khasan
# Processing Record 22 of Set 8 | marsh harbour
# Processing Record 23 of Set 8 | scalloway
# City not found. Skipping...
# Processing Record 24 of Set 8 | fukue
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | batamshinskiy
# Processing Record 27 of Set 8 | qasigiannguit
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | moroto
# Processing Record 30 of Set 8 | bratsk
# Processing Record 31 of Set 8 | tangshan
# Processing Record 32 of Set 8 | simbahan
# Processing Record 33 of Set 8 | altay
# Processing Record 34 of Set 8 | ziro
# Processing Record 35 of Set 8 | mayna
# Processing Record 36 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 8 | padilla
# Processing Record 38 of Set 8 | charters towers
# Processing Record 39 of Set 8 | praia da vitoria
# Processing Record 40 of Set 8 | umm kaddadah
# Processing Record 41 of Set 8 | wanning
# Processing Record 42 of Set 8 | san ramon
# Processing Record 43 of Set 8 | lompoc
# Processing Record 44 of Set 8 | rocha
# Processing Record 45 of Set 8 | prado
# Processing Record 46 of Set 8 | giaveno
# Processing Record 47 of Set 8 | ferrol
# Processing Record 48 of Set 8 | manicore
# Processing Record 49 of Set 8 | san cristobal
# Processing Record 50 of Set 8 | pathein
# Processing Record 1 of Set 9 | velykyy burluk
# Processing Record 2 of Set 9 | vao
# Processing Record 3 of Set 9 | takoradi
# Processing Record 4 of Set 9 | ribeira brava
# Processing Record 5 of Set 9 | batticaloa
# Processing Record 6 of Set 9 | lima
# Processing Record 7 of Set 9 | itarema
# Processing Record 8 of Set 9 | kilmez
# City not found. Skipping...
# Processing Record 9 of Set 9 | fort smith
# Processing Record 10 of Set 9 | ahuimanu
# Processing Record 11 of Set 9 | mana
# Processing Record 12 of Set 9 | warragul
# Processing Record 13 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 9 | coihaique
# Processing Record 15 of Set 9 | gushi
# Processing Record 16 of Set 9 | ixtapa
# Processing Record 17 of Set 9 | hay river
# Processing Record 18 of Set 9 | vetapalem
# Processing Record 19 of Set 9 | axim
# Processing Record 20 of Set 9 | ayr
# Processing Record 21 of Set 9 | beringovskiy
# Processing Record 22 of Set 9 | san juan
# Processing Record 23 of Set 9 | lamu
# Processing Record 24 of Set 9 | yarim
# Processing Record 25 of Set 9 | ilirska bistrica
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | baturaja
# Processing Record 28 of Set 9 | fallon
# Processing Record 29 of Set 9 | bay city
# Processing Record 30 of Set 9 | gallup
# Processing Record 31 of Set 9 | mayo
# Processing Record 32 of Set 9 | zalantun
# Processing Record 33 of Set 9 | lumphat
# Processing Record 34 of Set 9 | linguere
# Processing Record 35 of Set 9 | pirapozinho
# Processing Record 36 of Set 9 | nivala
# Processing Record 37 of Set 9 | valer
# Processing Record 38 of Set 9 | tual
# Processing Record 39 of Set 9 | glushkovo
# Processing Record 40 of Set 9 | gueret
# Processing Record 41 of Set 9 | mattru
# Processing Record 42 of Set 9 | matara
# Processing Record 43 of Set 9 | port hardy
# Processing Record 44 of Set 9 | moron
# Processing Record 45 of Set 9 | mae hong son
# Processing Record 46 of Set 9 | arlit
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | buchanan
# Processing Record 49 of Set 9 | grand gaube
# Processing Record 50 of Set 9 | dedougou
# Processing Record 1 of Set 10 | beni
# Processing Record 2 of Set 10 | aitape
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | gazanjyk
# Processing Record 5 of Set 10 | mutoko
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | pekalongan
# Processing Record 8 of Set 10 | langsa
# Processing Record 9 of Set 10 | hurghada
# Processing Record 10 of Set 10 | valle de allende
# Processing Record 11 of Set 10 | amazar
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | zhanakorgan
# Processing Record 14 of Set 10 | ler
# Processing Record 15 of Set 10 | el campo
# Processing Record 16 of Set 10 | silvan
# Processing Record 17 of Set 10 | kenai
# Processing Record 18 of Set 10 | uray
# Processing Record 19 of Set 10 | szilvasvarad
# Processing Record 20 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | kysyl-syr
# Processing Record 23 of Set 10 | buraydah
# Processing Record 24 of Set 10 | tanout
# Processing Record 25 of Set 10 | sundargarh
# Processing Record 26 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 10 | kamina
# Processing Record 28 of Set 10 | cabanas
# Processing Record 29 of Set 10 | taltal
# Processing Record 30 of Set 10 | sinnamary
# Processing Record 31 of Set 10 | hervey bay
# Processing Record 32 of Set 10 | aripuana
# Processing Record 33 of Set 10 | araouane
# Processing Record 34 of Set 10 | laramie
# Processing Record 35 of Set 10 | monte santo
# Processing Record 36 of Set 10 | san ignacio
# Processing Record 37 of Set 10 | muyezerskiy
# Processing Record 38 of Set 10 | san pedro
# Processing Record 39 of Set 10 | college
# Processing Record 40 of Set 10 | manggar
# Processing Record 41 of Set 10 | campos sales
# Processing Record 42 of Set 10 | kushima
# Processing Record 43 of Set 10 | uige
# Processing Record 44 of Set 10 | panguipulli
# Processing Record 45 of Set 10 | viedma
# Processing Record 46 of Set 10 | leh
# Processing Record 47 of Set 10 | mount darwin
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | vilcun
# Processing Record 50 of Set 10 | alice springs
# Processing Record 1 of Set 11 | port lincoln
# Processing Record 2 of Set 11 | talas
# Processing Record 3 of Set 11 | son la
# Processing Record 4 of Set 11 | ankang
# Processing Record 5 of Set 11 | maloy
# Processing Record 6 of Set 11 | hobyo
# Processing Record 7 of Set 11 | westport
# Processing Record 8 of Set 11 | huancabamba
# Processing Record 9 of Set 11 | bintulu
# Processing Record 10 of Set 11 | saint-augustin
# Processing Record 11 of Set 11 | karpogory
# Processing Record 12 of Set 11 | barreirinhas
# Processing Record 13 of Set 11 | luau
# Processing Record 14 of Set 11 | vangaindrano
# Processing Record 15 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 11 | la rioja
# Processing Record 17 of Set 11 | san-pedro
# Processing Record 18 of Set 11 | chifeng
# Processing Record 19 of Set 11 | bondo
# Processing Record 20 of Set 11 | hambantota
# Processing Record 21 of Set 11 | nantucket
# Processing Record 22 of Set 11 | terra santa
# Processing Record 23 of Set 11 | tezu
# Processing Record 24 of Set 11 | buin
# Processing Record 25 of Set 11 | setermoen
# Processing Record 26 of Set 11 | acajutla
# Processing Record 27 of Set 11 | ishurdi
# Processing Record 28 of Set 11 | safford
# Processing Record 29 of Set 11 | sambava
# Processing Record 30 of Set 11 | sur
# Processing Record 31 of Set 11 | makat
# Processing Record 32 of Set 11 | katobu
# Processing Record 33 of Set 11 | bafq
# Processing Record 34 of Set 11 | nakasongola
# Processing Record 35 of Set 11 | iseyin
# Processing Record 36 of Set 11 | povenets
# Processing Record 37 of Set 11 | fortuna foothills
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | neiafu
# Processing Record 40 of Set 11 | adrar
# Processing Record 41 of Set 11 | chuy
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | marmaron
# City not found. Skipping...
# Processing Record 44 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 11 | ovalle
# Processing Record 46 of Set 11 | trairi
# Processing Record 47 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 11 | pitkyaranta
# Processing Record 49 of Set 11 | matay
# Processing Record 50 of Set 11 | laguna
# Processing Record 1 of Set 12 | aksarka
# Processing Record 2 of Set 12 | monroe
# Processing Record 3 of Set 12 | margate
# Processing Record 4 of Set 12 | bam
# Processing Record 5 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 12 | navsari
# Processing Record 7 of Set 12 | leland
# Processing Record 8 of Set 12 | presidencia roque saenz pena
# Processing Record 9 of Set 12 | aquiraz
# Processing Record 10 of Set 12 | guiratinga
# Processing Record 11 of Set 12 | staraya toropa
# Processing Record 12 of Set 12 | maltahohe
# Processing Record 13 of Set 12 | qui nhon
# Processing Record 14 of Set 12 | ravar
# Processing Record 15 of Set 12 | saint-prosper
# Processing Record 16 of Set 12 | khuzhir
# Processing Record 17 of Set 12 | gangawati
# Processing Record 18 of Set 12 | trat
# Processing Record 19 of Set 12 | fairbanks
# Processing Record 20 of Set 12 | bundu
# Processing Record 21 of Set 12 | aykhal
# Processing Record 22 of Set 12 | manadhoo
# Processing Record 23 of Set 12 | ketchikan
# Processing Record 24 of Set 12 | carora
# Processing Record 25 of Set 12 | hami
# Processing Record 26 of Set 12 | sao jose da coroa grande
# Processing Record 27 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 12 | huntsville
# Processing Record 29 of Set 12 | goderich
# Processing Record 30 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 12 | garhshankar
# Processing Record 32 of Set 12 | turiacu
# Processing Record 33 of Set 12 | pangody
# Processing Record 34 of Set 12 | bezhetsk
# Processing Record 35 of Set 12 | texarkana
# Processing Record 36 of Set 12 | miraflores
# Processing Record 37 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 12 | rio gallegos
# Processing Record 39 of Set 12 | loa janan
# Processing Record 40 of Set 12 | trincomalee
# Processing Record 41 of Set 12 | paita
# Processing Record 42 of Set 12 | kachug
# Processing Record 43 of Set 12 | himora
# City not found. Skipping...
# Processing Record 44 of Set 12 | port-cartier
# Processing Record 45 of Set 12 | snyder
# Processing Record 46 of Set 12 | bandon
# Processing Record 47 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 48 of Set 12 | indi
# Processing Record 49 of Set 12 | antalaha
# Processing Record 50 of Set 12 | urumqi
# Processing Record 1 of Set 13 | erenhot
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | turukhansk
# Processing Record 4 of Set 13 | eau claire
# Processing Record 5 of Set 13 | bonbon
# Processing Record 6 of Set 13 | lusambo
# Processing Record 7 of Set 13 | kiunga
# Processing Record 8 of Set 13 | petrovsk-zabaykalskiy
# Processing Record 9 of Set 13 | nabire
# Processing Record 10 of Set 13 | ranong
# Processing Record 11 of Set 13 | kudahuvadhoo
# Processing Record 12 of Set 13 | rudbar
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | varna
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | grindavik
# Processing Record 17 of Set 13 | portland
# Processing Record 18 of Set 13 | whyalla
# Processing Record 19 of Set 13 | pitimbu
# Processing Record 20 of Set 13 | camacha
# Processing Record 21 of Set 13 | kholodnyy
# Processing Record 22 of Set 13 | iquitos
# Processing Record 23 of Set 13 | tres arroyos
# Processing Record 24 of Set 13 | telimele
# Processing Record 25 of Set 13 | ust-omchug
# Processing Record 26 of Set 13 | homer
# Processing Record 27 of Set 13 | mahuta
# Processing Record 28 of Set 13 | pontianak
# Processing Record 29 of Set 13 | sao geraldo do araguaia
# Processing Record 30 of Set 13 | krasnorechenskiy
# Processing Record 31 of Set 13 | derzhavinsk
# Processing Record 32 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 13 | mala danylivka
# Processing Record 34 of Set 13 | valparaiso
# Processing Record 35 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 36 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 13 | kismayo
# Processing Record 38 of Set 13 | saint-pierre
# Processing Record 39 of Set 13 | tiarei
# Processing Record 40 of Set 13 | jaswantnagar
# Processing Record 41 of Set 13 | solnechnyy
# Processing Record 42 of Set 13 | olinda
# Processing Record 43 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 13 | garowe
# Processing Record 46 of Set 13 | pecos
# Processing Record 47 of Set 13 | dongargaon
# Processing Record 48 of Set 13 | yumen
# Processing Record 49 of Set 13 | nanortalik
# Processing Record 50 of Set 13 | great yarmouth
# Processing Record 1 of Set 14 | dingle
# Processing Record 2 of Set 14 | igarka
# Processing Record 3 of Set 14 | sarangani
# Processing Record 4 of Set 14 | ostrovnoy
# Processing Record 5 of Set 14 | kalabo
# Processing Record 6 of Set 14 | pangai
# Processing Record 7 of Set 14 | narsaq
# Processing Record 8 of Set 14 | lebedinyy
# Processing Record 9 of Set 14 | ogaminana
# Processing Record 10 of Set 14 | kyenjojo
# Processing Record 11 of Set 14 | yanam
# Processing Record 12 of Set 14 | chicama
# Processing Record 13 of Set 14 | horsham
# Processing Record 14 of Set 14 | baiyin
# Processing Record 15 of Set 14 | shingu
# Processing Record 16 of Set 14 | kota kinabalu
# Processing Record 17 of Set 14 | redcliffe
# Processing Record 18 of Set 14 | la asuncion
# Processing Record 19 of Set 14 | luanda
# Processing Record 20 of Set 14 | sistranda
# Processing Record 21 of Set 14 | tilichiki
# Processing Record 22 of Set 14 | samarai
# Processing Record 23 of Set 14 | biharamulo
# Processing Record 24 of Set 14 | yilan
# Processing Record 25 of Set 14 | jeremie
# Processing Record 26 of Set 14 | qandala
# Processing Record 27 of Set 14 | lazaro cardenas
# Processing Record 28 of Set 14 | japura
# Processing Record 29 of Set 14 | karistos
# City not found. Skipping...
# Processing Record 30 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 31 of Set 14 | atakpame
# Processing Record 32 of Set 14 | monrovia
# Processing Record 33 of Set 14 | selikhino
# Processing Record 34 of Set 14 | havelock
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | fruitvale
# Processing Record 37 of Set 14 | meulaboh
# Processing Record 38 of Set 14 | santa
# Processing Record 39 of Set 14 | moree
# Processing Record 40 of Set 14 | excelsior springs
# Processing Record 41 of Set 14 | vanimo
# Processing Record 42 of Set 14 | karaton
# Processing Record 43 of Set 14 | vaitape
# Processing Record 44 of Set 14 | ilo
# Processing Record 45 of Set 14 | ciudad bolivar
# Processing Record 46 of Set 14 | taksimo
# Processing Record 47 of Set 14 | saint-joseph
# Processing Record 48 of Set 14 | sobolevo
# Processing Record 49 of Set 14 | shenjiamen
# Processing Record 50 of Set 14 | sarkand
# Processing Record 1 of Set 15 | iroquois falls
# Processing Record 2 of Set 15 | novyy buh
# Processing Record 3 of Set 15 | bambanglipuro
# Processing Record 4 of Set 15 | amahai
# Processing Record 5 of Set 15 | tiznit
# Processing Record 6 of Set 15 | nouakchott
# Processing Record 7 of Set 15 | mudanya
# Processing Record 8 of Set 15 | los llanos de aridane
# Processing Record 9 of Set 15 | young
# Processing Record 10 of Set 15 | apad
# Processing Record 11 of Set 15 | santo antonio da platina
# Processing Record 12 of Set 15 | ossora
# Processing Record 13 of Set 15 | otradnoye
# Processing Record 14 of Set 15 | mayumba
# Processing Record 15 of Set 15 | abu samrah
# Processing Record 16 of Set 15 | kathu
# Processing Record 17 of Set 15 | namibe
# Processing Record 18 of Set 15 | revelstoke
# Processing Record 19 of Set 15 | chodavaram
# Processing Record 20 of Set 15 | qingyuan
# Processing Record 21 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 22 of Set 15 | guanica
# Processing Record 23 of Set 15 | novo aripuana
# Processing Record 24 of Set 15 | rio grande
# Processing Record 25 of Set 15 | lianzhou
# Processing Record 26 of Set 15 | sola
# Processing Record 27 of Set 15 | olavarria
# Processing Record 28 of Set 15 | sandane
# Processing Record 29 of Set 15 | marsassoum
# Processing Record 30 of Set 15 | bitung
# Processing Record 31 of Set 15 | columbus
# Processing Record 32 of Set 15 | banda aceh
# Processing Record 33 of Set 15 | mama
# Processing Record 34 of Set 15 | piranshahr
# Processing Record 35 of Set 15 | barcelos
# Processing Record 36 of Set 15 | ajdabiya
# Processing Record 37 of Set 15 | vallenar
# Processing Record 38 of Set 15 | kachiry
# Processing Record 39 of Set 15 | george town
# Processing Record 40 of Set 15 | verkhnetulomskiy
# Processing Record 41 of Set 15 | sao felix do xingu
# Processing Record 42 of Set 15 | ucluelet
# Processing Record 43 of Set 15 | murray bridge
# Processing Record 44 of Set 15 | paso de carrasco
# Processing Record 45 of Set 15 | dalaba
# Processing Record 46 of Set 15 | half moon bay
# Processing Record 47 of Set 15 | trapani
# Processing Record 48 of Set 15 | henties bay
# Processing Record 49 of Set 15 | turkistan
# Processing Record 50 of Set 15 | howard springs
# Processing Record 1 of Set 16 | guanhaes
# Processing Record 2 of Set 16 | fossano
# Processing Record 3 of Set 16 | weston
# Processing Record 4 of Set 16 | smithers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kaitangata -46.2817  169.8464     50.43        77         100
# 1     Clyde River  70.4692  -68.5914    -10.97        84         100
# 2     San Quintin  30.4833 -115.9500     62.89        45         100
# 3          Caxias  38.7031   -9.2767     63.91        79          40
# 4  Port Elizabeth -33.9180   25.5701     64.69        74          20
# 5           Bluff -46.6000  168.3333     50.32        74          69
# 6       Fengcheng  40.4536  124.0717     20.68        97         100
# 7         Mataura -46.1927  168.8643     48.83        80          99
# 8         Pinczow  50.5205   20.5265     34.61        90         100
# 9   Leningradskiy  69.3833  178.4167     -0.42        85          25
#
#    Wind Speed Country Current Description
# 0        6.71      NZ     overcast clouds
# 1        3.44      CA     overcast clouds
# 2        6.22      MX     overcast clouds
# 3        9.22      PT    scattered clouds
# 4        9.22      ZA          few clouds
# 5       11.70      NZ       broken clouds
# 6        2.33      CN          light snow
# 7        3.11      NZ     overcast clouds
# 8        5.32      PL     overcast clouds
# 9        6.73      RU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Kaitangata      NZ -46.2817  169.8464     50.43        77
# 1       Clyde River      CA  70.4692  -68.5914    -10.97        84
# 2       San Quintin      MX  30.4833 -115.9500     62.89        45
# 3            Caxias      PT  38.7031   -9.2767     63.91        79
# 4    Port Elizabeth      ZA -33.9180   25.5701     64.69        74
# ..              ...     ...      ...       ...       ...       ...
# 686  Howard Springs      AU -12.4970  131.0470     76.91        97
# 687        Guanhaes      BR -18.7750  -42.9325     68.76        96
# 688         Fossano      IT  44.5489    7.7201     52.43        93
# 689          Weston      US  26.1004  -80.3998     80.02        67
# 690        Smithers      CA  54.7804 -127.1743    -25.28        75
#
#      Cloudiness  Wind Speed Current Description
# 0           100        6.71     overcast clouds
# 1           100        3.44     overcast clouds
# 2           100        6.22     overcast clouds
# 3            40        9.22    scattered clouds
# 4            20        9.22          few clouds
# ..          ...         ...                 ...
# 686         100        4.09       moderate rain
# 687         100        3.67          light rain
# 688          20        3.44          few clouds
# 689         100       13.00     overcast clouds
# 690          20        4.61          few clouds
#
# [691 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
